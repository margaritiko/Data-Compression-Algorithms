# %%
import numpy as np
import pandas as pd

# %%
frequency_data = pd.read_csv("frequency.csv")

# %%
frequency_data.head(255)
# Out:
#      data.pptx  books.txt  blue_book.pdf  file.docx  paintings.jpg  \
# 0     0.032372        0.0       0.009049   0.009219       0.007906
# 1     0.004306        0.0       0.003256   0.004221       0.003215
# 2     0.003745        0.0       0.003432   0.003633       0.002178
# 3     0.004542        0.0       0.003465   0.004411       0.004390
# 4     0.003622        0.0       0.003048   0.004083       0.003216
# ..         ...        ...            ...        ...            ...
# 250   0.003603        0.0       0.004913   0.003642       0.004839
# 251   0.003792        0.0       0.004560   0.003748       0.003320
# 252   0.003660        0.0       0.005789   0.004177       0.004206
# 253   0.003714        0.0       0.005433   0.003667       0.003494
# 254   0.003542        0.0       0.005860   0.003976       0.003549
#
#      gray-photo.jpg  marbles.BMP  mystery.bmp   wmp.dll  program.exe  \
# 0          0.015146     0.087539     0.001188  0.135903     0.014504
# ...

# %%
overall_data = pd.read_csv("overall.csv")

# %%
overall_data.head()
# Out:
#        S1  H    SF_S2      SF_K   SF_TU    SF_TP  LZ77_5_S2  LZ77_5_K  \
# 0 -344083  0  4548.54 -0.013219  8.9271  9.39219    8325.85 -0.024197
#
#    LZ77_5_TU  LZ77_5_TP  ...  LZ77_10_TU  LZ77_10_TP  LZ77_20_S2  LZ77_20_K  \
# 0    124.842    101.642  ...     9.02993     241.313     8273.86  -0.024046
#
#    LZ77_20_TU  LZ77_20_TP   LZW_S2     LZW_K   LZW_TU   LZW_TP
# 0     8.76153     305.547  8076.54 -0.023473  19.1882  18.0131
#
# [1 rows x 22 columns]
